# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
#!pip install wordcloud

# %%
df = pd.read_csv('https://media.githubusercontent.com/media/DBertazioli/ARmeetup/master/Visualizations/wordcloud/event_topic_keywords_selected_country.csv')

# %%
df.head()
# Out:
#           ID       City Country  \
# 0  259064919  Liverpool      gb
# 1  260307100  Stuttgart      de
# 2  260306857  Stuttgart      de
# 3  260306983  Stuttgart      de
# 4  260306926  Stuttgart      de
#
#                                             Keywords
# 0  ['Well-being', 'Spirituality', 'Social', 'Sing...
# 1  ['Community', 'Business', 'Tech', 'Education',...
# 2  ['Community', 'Business', 'Tech', 'Education',...
# 3  ['Community', 'Business', 'Tech', 'Education',...
# 4  ['Community', 'Business', 'Tech', 'Education',...

# %%
len(df)
# Out:
# 56063

# %%
text = ''.join(df.Keywords)
text = text.replace("\'","")
print ("There are {} words in this country".format(len(text)))
# Out:
# There are 1676821 words in this country

# %%
type(text)
# Out:
# str

# %%
wc = WordCloud(max_font_size=60, max_words=1000, background_color="white").generate(text)
plt.figure(figsize=(10,8))
plt.imshow(wc, interpolation='hamming')
plt.axis("off")
#plt.show()
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
#to save
#wordcloud.to_file("img/first_review.png")

# %%
#when problem with 0,0.. --> 255, 255..

'''def transform_format(val):
    if val == 0:
        return 255
    else:
        return val

transformed_mask = np.ndarray((mask.shape[0],mask.shape[1]), np.int32)

for i in range(len(mask)):
    transformed_mask[i] = list(map(transform_format, mask[i]))

transformed_mask'''

# %% [markdown]
# # List of european country

# %%
df_es = df[df['Country']=='es']
df_it = df[df['Country']=='it']
df_pt = df[df['Country']=='pt']
df_se = df[df['Country']=='se']
df_gb = df[df['Country']=='gb']
df_fi = df[df['Country']=='fi']
df_fr = df[df['Country']=='fr']
df_nl = df[df['Country']=='nl']
df_de = df[df['Country']=='de']

# %% [markdown]
# ## Create text for generate wordcloud by country

# %%
text_es = ''.join(df_es.Keywords).replace("\'","")
text_it = ''.join(df_it.Keywords).replace("\'","")
text_pt = ''.join(df_pt.Keywords).replace("\'","")
text_se = ''.join(df_se.Keywords).replace("\'","")
text_gb = ''.join(df_gb.Keywords).replace("\'","")
text_fi = ''.join(df_fi.Keywords).replace("\'","")
text_fr = ''.join(df_fr.Keywords).replace("\'","")
text_nl = ''.join(df_nl.Keywords).replace("\'","")
text_de = ''.join(df_de.Keywords).replace("\'","")
print ("There are {} words in espana\n\
There are {} words in italy\n\
There are {} words in portugal\n\
There are {} words in sweden\n\
There are {} words in gran bretain\n\
There are {} words in finland\n\
There are {} words in france\n\
There are {} words in netherlands\n\
There are {} words in germany\n".format(len(text_es),len(text_it),len(text_pt),len(text_se),len(text_gb)
                                       ,len(text_fi),len(text_fr),len(text_nl),len(text_de)))
# Out:
# There are 278048 words in espana
# There are 28475 words in italy
# There are 20467 words in portugal
# There are 25751 words in sweden
# There are 843969 words in gran bretain
# There are 5116 words in finland
# There are 183175 words in france
# There are 85550 words in netherlands
# There are 206270 words in germany

# %% [markdown]
# ## Load mask for color by country

# %%
mask_es = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/es.png"))
mask_it = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/it.png"))
mask_pt = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/pt.png"))
mask_se = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/se.png"))
mask_gb = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/gb.png"))
mask_fi = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/fi.png"))
mask_fr = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/fr.png"))
mask_nl = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/nl.png"))
mask_de = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/de.png"))

# %% [markdown]
# ## Load mask for shape

# %%
shape_mask_es = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/es_shape.png"))
shape_mask_it = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/it_shape.png"))
shape_mask_pt = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/pt_shape.png"))
shape_mask_se = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/se_shape.png"))
shape_mask_gb = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/gb_shape.png"))
shape_mask_fi = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/fi_shape.png"))
shape_mask_fr = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/fr_shape.png"))
shape_mask_nl = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/nl_shape.png"))
shape_mask_de = np.array(Image.open("I:/Massi/Documents/GitHub/ARmeetup/Visualizations/flag_country/de_shape.png"))

# %% [markdown]
# # Spain

# %%
#check
df_es.head(3)
# Out:
#            ID       City Country  \
# 7   260071756  Barcelona      es
# 8   260509150  Barcelona      es
# 12  260118462     Madrid      es
#
#                                              Keywords
# 7                                            ['Tech']
# 8                                            ['Tech']
# 12  ['Outdoors', 'Social', 'Community', 'Photograp...

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_es, width=800,height=400).generate(text_es)
image_colors = ImageColorGenerator(mask_es)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
#plt.savefig("wordcloud_flag_es.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_es.png")
# Out:
# (-0.5, 1999.5, 1332.5, -0.5)

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_es).generate(text_es)
image_colors = ImageColorGenerator(mask_es)
# store to file
#wc.to_file("img/wordcloud_shape_es.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_es.png", facecolor='none')
#plt.show()

# %% [markdown]
# # Italy

# %%
df_it.head(3)
# Out:
#             ID    City Country                         Keywords
# 35   260049539  Ancona      it  ['Tech', 'Education', 'Crafts']
# 159  260140455    Roma      it                         ['Tech']
# 160  259295022    Roma      it                         ['Tech']

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_it).generate(text_it)
image_colors = ImageColorGenerator(mask_it)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
#plt.savefig("wordcloud_flag_it.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_it.png")
# Out:
# (-0.5, 1999.5, 1332.5, -0.5)

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_it, repeat=True, font_step=1).generate(text_it)
image_colors = ImageColorGenerator(shape_mask_it)
# store to file
#wc.to_file("img/wordcloud_shape_it.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_it.png", facecolor='none')
#plt.show()

# %% [markdown]
# # Portugal

# %%
df_pt.head(3)
# Out:
#             ID    City Country    Keywords
# 211  260110559  Lisbon      pt  ['Sports']
# 212  260532354  Lisbon      pt  ['Sports']
# 213  260110549  Lisbon      pt  ['Sports']

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_pt, repeat=False).generate(text_pt)
image_colors = ImageColorGenerator(mask_pt)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.savefig("wordcloud_flag_pt.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_pt.png")

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_pt).generate(text_pt)
image_colors = ImageColorGenerator(shape_mask_pt)
# store to file
#wc.to_file("img/wordcloud_shape_pt.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_pt.png", facecolor='none')
#plt.show()

# %% [markdown]
# # Sweden

# %%
df_se.head(3)
# Out:
#               ID        City Country  \
# 39     259088601  Bor\u00e5s      se
# 78  srzgvqyzgbdb   Stockholm      se
# 79  dfrwqqyzgbdb   Stockholm      se
#
#                                         Keywords
# 39                         ['Tech', 'Languages']
# 78  ['Fitness', 'Sports', 'Crafts', 'Languages']
# 79  ['Fitness', 'Sports', 'Crafts', 'Languages']

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_se, repeat=False).generate(text_se)
image_colors = ImageColorGenerator(mask_se)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.savefig("wordcloud_flag_se.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_se.png")

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_se).generate(text_se)
image_colors = ImageColorGenerator(shape_mask_se)
# store to file
#wc.to_file("img/wordcloud_shape_se.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_se.png", facecolor='none')
#plt.show()

# %% [markdown]
# # GB

# %%
df_gb.head(3)
# Out:
#               ID       City Country  \
# 0      259064919  Liverpool      gb
# 9   qbjlnqyzhbrb     London      gb
# 10     260272758     London      gb
#
#                                              Keywords
# 0   ['Well-being', 'Spirituality', 'Social', 'Sing...
# 9                      ['Well-being', 'Spirituality']
# 10                     ['Well-being', 'Spirituality']

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_gb, repeat=False).generate(text_gb)
image_colors = ImageColorGenerator(mask_gb)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.savefig("wordcloud_flag_gb.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_gb.png")

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_gb).generate(text_gb)
image_colors = ImageColorGenerator(mask_gb)
# store to file
#wc.to_file("img/wordcloud_shape_gb.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_gb.png", facecolor='none')
#plt.show()

# %% [markdown]
# # Finland

# %%
df_fi.head(3)
# Out:
#            ID      City Country                                  Keywords
# 23  259129795  Helsinki      fi                      ['Tech', 'Business']
# 50  260470148  Helsinki      fi  ['Social', 'Spirituality', 'Well-being']
# 51  260470169  Helsinki      fi  ['Social', 'Spirituality', 'Well-being']

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_fi, repeat=False).generate(text_fi)
image_colors = ImageColorGenerator(mask_fi)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.savefig("wordcloud_flag_fi.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_fi.png")

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_fi, repeat=True).generate(text_fi)
image_colors = ImageColorGenerator(shape_mask_fi)
# store to file
#wc.to_file("img/wordcloud_shape_fi.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_fi.png", facecolor='none')
#plt.show()

# %% [markdown]
# # France

# %%
df_fr.head(3)
# Out:
#             ID       City Country         Keywords
# 144  260082387  Rochefort      fr         ['Tech']
# 163  260278206   Mulhouse      fr  ['Photography']
# 164  260278143   Mulhouse      fr  ['Photography']

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_fr, repeat=False).generate(text_fr)
image_colors = ImageColorGenerator(mask_fr)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
#plt.savefig("wordcloud_flag_fr.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_fr.png")

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_fr).generate(text_fr)
image_colors = ImageColorGenerator(shape_mask_fr)
# store to file
#wc.to_frle("img/wordcloud_shape_fr.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_fr.png", facecolor='none')
#plt.show()

# %% [markdown]
# # Netherlands

# %%
df_nl.head(3)
# Out:
#               ID       City Country                       Keywords
# 13     260456805  Amsterdam      nl  ['Languages', 'Food & Drink']
# 14  bnqpsqyzgbxb  Amsterdam      nl  ['Languages', 'Food & Drink']
# 15     259326828  Amsterdam      nl  ['Languages', 'Food & Drink']

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_nl, repeat=False).generate(text_nl)
image_colors = ImageColorGenerator(mask_nl)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
#plt.savefig("wordcloud_flag_nl.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_nl.png")
# Out:
# (-0.5, 1279.5, 852.5, -0.5)

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_nl).generate(text_nl)
image_colors = ImageColorGenerator(shape_mask_nl)
# store to file
#wc.to_nlle("img/wordcloud_shape_nl.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_nl.png", facecolor='none')
#plt.show()

# %% [markdown]
# # Germany

# %%
df_de.head(3)
# Out:
#           ID       City Country  \
# 1  260307100  Stuttgart      de
# 2  260306857  Stuttgart      de
# 3  260306983  Stuttgart      de
#
#                                             Keywords
# 1  ['Community', 'Business', 'Tech', 'Education',...
# 2  ['Community', 'Business', 'Tech', 'Education',...
# 3  ['Community', 'Business', 'Tech', 'Education',...

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=mask_de, repeat=False).generate(text_de)
image_colors = ImageColorGenerator(mask_de)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
#plt.savefig("wordcloud_flag_de.png", facecolor='none')
#plt.show()
#wc.to_file("wordcloud_flag_de.png")
# Out:
# (-0.5, 1023.5, 613.5, -0.5)

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=shape_mask_de).generate(text_de)
image_colors = ImageColorGenerator(shape_mask_de)
# store to file
#wc.to_dele("img/wordcloud_shape_de.png")
# show
plt.figure(figsize=[14,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud_shape_de.png", facecolor='none')
#plt.show()
